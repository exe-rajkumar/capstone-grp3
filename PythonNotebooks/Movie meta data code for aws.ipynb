# %%
import pandas as pd
import ast

# %%
meta=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\Capstone Project 3\Capstone Project 3\Data\movies_metadata.csv')
# Out:
# C:\Users\sambangi.bindu\AppData\Local\Temp\ipykernel_21488\2182780873.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\Capstone Project 3\Capstone Project 3\Data\movies_metadata.csv')

# %%
meta.rename(columns={'id':'mov_id'},inplace=True)

# %%
meta
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
meta.shape
# Out:
# (45466, 24)

# %% [markdown]
# # Data cleaning in movie meta data

# %%
meta[meta.duplicated()]
# Out:
#        adult belongs_to_collection  budget  \
# 1465   False                   NaN       0
# 9165   False                   NaN       0
# 9327   False                   NaN       0
# 13375  False                   NaN       0
# 16764  False                   NaN       0
# 21165  False                   NaN       0
# 21854  False                   NaN       0
# 22151  False                   NaN       0
# 23044  False                   NaN       0
# 24844  False                   NaN       0
# 28860  False                   NaN       0
# 29374  False                   NaN       0
# 40040  False                   NaN  980000
#
#                                                   genres  \
# 1465   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 9165   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 9327   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 13375  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 16764  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# ...

# %%
meta.drop_duplicates(inplace=True)

# %%
meta.shape
# Out:
# (45453, 24)

# %%
meta.drop(columns=['belongs_to_collection','genres','production_companies','production_countries','spoken_languages'],inplace=True)

# %%
meta.drop(columns=['homepage','overview','poster_path'],inplace=True)

# %%
meta
# Out:
#        adult    budget  mov_id    imdb_id original_language  \
# 0      False  30000000     862  tt0114709                en
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title popularity release_date      revenue  \
# 0                        Toy Story  21.946943   1995-10-30  373554033.0
# 1                          Jumanji  17.015539   1995-12-15  262797249.0
# ...

# %%
meta['mov_id'] = pd.to_numeric(meta['mov_id'], errors='coerce')
meta = meta.dropna(subset=['mov_id'], how='any')
#new_meta[new_meta['Mov_id'].isnull()==True]

# %%
meta
# Out:
#        adult    budget    mov_id    imdb_id original_language  \
# 0      False  30000000     862.0  tt0114709                en
# 1      False  65000000    8844.0  tt0113497                en
# 2      False         0   15602.0  tt0113228                en
# 3      False  16000000   31357.0  tt0114885                en
# 4      False         0   11862.0  tt0113041                en
# ...      ...       ...       ...        ...               ...
# 45461  False         0  439050.0  tt6209470                fa
# 45462  False         0  111109.0  tt2028550                tl
# 45463  False         0   67758.0  tt0303758                en
# 45464  False         0  227506.0  tt0008536                en
# 45465  False         0  461257.0  tt6980792                en
#
#                     original_title popularity release_date      revenue  \
# 0                        Toy Story  21.946943   1995-10-30  373554033.0
# 1                          Jumanji  17.015539   1995-12-15  262797249.0
# ...

# %%
meta.isnull().sum()
# Out:
# adult                    0
# budget                   0
# mov_id                   0
# imdb_id                 17
# original_language       11
# original_title           0
# popularity               3
# release_date            87
# revenue                  3
# runtime                260
# status                  84
# tagline              25042
# title                    3
# video                    3
# vote_average             3
# vote_count               3
# dtype: int64

# %%
meta[meta['revenue'].isnull()==True][['revenue','status','title','video','vote_average','vote_count','popularity']]
# Out:
#        revenue status title video  vote_average  vote_count popularity
# 19729      NaN    NaN   NaN   NaN           NaN         NaN        NaN
# 29502      NaN    NaN   NaN   NaN           NaN         NaN        NaN
# 35586      NaN    NaN   NaN   NaN           NaN         NaN        NaN

# %%
meta[meta['revenue'].isnull()==True][['revenue','status','title','video','vote_average','vote_count','imdb_id','original_language','release_date','runtime','tagline','popularity']]
# Out:
#        revenue status title video  vote_average  vote_count    imdb_id  \
# 19729      NaN    NaN   NaN   NaN           NaN         NaN  tt0113002
# 29502      NaN    NaN   NaN   NaN           NaN         NaN  tt2423504
# 35586      NaN    NaN   NaN   NaN           NaN         NaN  tt2622826
#
#       original_language release_date  runtime tagline popularity
# 19729                en          NaN      NaN     NaN        NaN
# 29502                ja          NaN      NaN     NaN        NaN
# 35586                en          NaN      NaN     NaN        NaN

# %%
a=meta.isnull().sum(axis=1)
b=a.max()
rows_with_max_nulls = meta[a == b]

# %%
rows_with_max_nulls
# Out:
#        adult budget    mov_id    imdb_id original_language    original_title  \
# 19729  False      0   82663.0  tt0113002                en      Midnight Man
# 29502  False      0  122662.0  tt2423504                ja  マルドゥック・スクランブル 排気
# 35586  False      0  249260.0  tt2622826                en  Avalanche Sharks
#
#       popularity release_date  revenue  runtime status tagline title video  \
# 19729        NaN          NaN      NaN      NaN    NaN     NaN   NaN   NaN
# 29502        NaN          NaN      NaN      NaN    NaN     NaN   NaN   NaN
# 35586        NaN          NaN      NaN      NaN    NaN     NaN   NaN   NaN
#
#        vote_average  vote_count
# 19729           NaN         NaN
# 29502           NaN         NaN
# 35586           NaN         NaN

# %%
meta.dropna(subset=['title'],how='any',inplace=True)
# Out:
# C:\Users\sambangi.bindu\AppData\Local\Temp\ipykernel_21488\1560785996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta.dropna(subset=['title'],how='any',inplace=True)

# %%
meta['imdb_id'] = meta['imdb_id'].str.replace('tt', '')
# Out:
# C:\Users\sambangi.bindu\AppData\Local\Temp\ipykernel_21488\2127178126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta['imdb_id'] = meta['imdb_id'].str.replace('tt', '')

# %%
meta['imdb_id']=meta['imdb_id'].astype(float)
# Out:
# C:\Users\sambangi.bindu\AppData\Local\Temp\ipykernel_21488\1161828766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta['imdb_id']=meta['imdb_id'].astype(float)

# %%
meta.dtypes
# Out:
# adult                 object
# budget                object
# mov_id               float64
# imdb_id              float64
# original_language     object
# original_title        object
# popularity            object
# release_date          object
# revenue              float64
# runtime              float64
# status                object
# tagline               object
# title                 object
# video                 object
# vote_average         float64
# vote_count           float64
# dtype: object

# %%
meta['adult'].value_counts()
# Out:
# False    45438
# True         9
# Name: adult, dtype: int64

# %%
meta
# Out:
#        adult    budget    mov_id    imdb_id original_language  \
# 0      False  30000000     862.0   114709.0                en
# 1      False  65000000    8844.0   113497.0                en
# 2      False         0   15602.0   113228.0                en
# 3      False  16000000   31357.0   114885.0                en
# 4      False         0   11862.0   113041.0                en
# ...      ...       ...       ...        ...               ...
# 45461  False         0  439050.0  6209470.0                fa
# 45462  False         0  111109.0  2028550.0                tl
# 45463  False         0   67758.0   303758.0                en
# 45464  False         0  227506.0     8536.0                en
# 45465  False         0  461257.0  6980792.0                en
#
#                     original_title popularity release_date      revenue  \
# 0                        Toy Story  21.946943   1995-10-30  373554033.0
# 1                          Jumanji  17.015539   1995-12-15  262797249.0
# ...

# %%
meta['adult'].value_counts()
# Out:
# False    45438
# True         9
# Name: adult, dtype: int64

# %%
meta['budget']=meta['budget'].astype(int)
# Out:
# C:\Users\sambangi.bindu\AppData\Local\Temp\ipykernel_21488\4045488092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta['budget']=meta['budget'].astype(int)

# %%
meta['popularity']=meta['popularity'].astype(float)
# Out:
# C:\Users\sambangi.bindu\AppData\Local\Temp\ipykernel_21488\672674034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta['popularity']=meta['popularity'].astype(float)

# %%
meta.dtypes
# Out:
# adult                 object
# budget                 int32
# mov_id               float64
# imdb_id              float64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# revenue              float64
# runtime              float64
# status                object
# tagline               object
# title                 object
# video                 object
# vote_average         float64
# vote_count           float64
# dtype: object

# %%
meta.isnull().sum()
# Out:
# adult                    0
# budget                   0
# mov_id                   0
# imdb_id                 17
# original_language       11
# original_title           0
# popularity               0
# release_date            84
# revenue                  0
# runtime                257
# status                  81
# tagline              25039
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
meta
# Out:
#        adult    budget    mov_id    imdb_id original_language  \
# 0      False  30000000     862.0   114709.0                en
# 1      False  65000000    8844.0   113497.0                en
# 2      False         0   15602.0   113228.0                en
# 3      False  16000000   31357.0   114885.0                en
# 4      False         0   11862.0   113041.0                en
# ...      ...       ...       ...        ...               ...
# 45461  False         0  439050.0  6209470.0                fa
# 45462  False         0  111109.0  2028550.0                tl
# 45463  False         0   67758.0   303758.0                en
# 45464  False         0  227506.0     8536.0                en
# 45465  False         0  461257.0  6980792.0                en
#
#                     original_title  popularity release_date      revenue  \
# 0                        Toy Story   21.946943   1995-10-30  373554033.0
# ...

# %%
meta[meta.duplicated()]
# Out:
#        adult  budget    mov_id    imdb_id original_language  \
# 35798  False       0  159849.0   173769.0                en
# 38871  False       0   99080.0    22537.0                en
# 40276  False       0   97995.0   127834.0                en
# 45265  False       0  265189.0  2121382.0                sv
#
#                          original_title  popularity release_date    revenue  \
# 35798  Why We Fight: Divide and Conquer    0.473322   1943-01-01        0.0
# 38871                        The Viking    0.002362   1931-06-21        0.0
# 40276              Seven Years Bad Luck    0.141558   1921-02-06        0.0
# 45265                            Turist   12.165685   2014-08-15  1359497.0
#
#        runtime    status                                            tagline  \
# 35798     57.0  Released                                                NaN
# 38871     70.0  Released  Actually produced during the Great Newfoundlan...
# ...

# %%
meta.drop_duplicates(inplace=True)

# %%
meta.to_csv('cleaned_mvi_data.csv',index=False)
