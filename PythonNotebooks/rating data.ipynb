# %%
import pandas as pd

# %%
df1=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\Capstone Project 3\Capstone Project 3\Data\links.csv')

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId]
# Index: []

# %%
df1.dtypes
# Out:
# movieId      int64
# imdbId       int64
# tmdbId     float64
# dtype: object

# %%
df1.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df1.shape
# Out:
# (45843, 3)

# %%
df2=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\Capstone Project 3\Capstone Project 3\Data\ratings.csv')

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %%
df2.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
df2.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
df2.shape
# Out:
# (26024289, 4)

# %%
a=df2.groupby('movieId')['rating'].mean().reset_index()

# %%
a
# Out:
#        movieId    rating
# 0            1  3.888157
# 1            2  3.236953
# 2            3  3.175550
# 3            4  2.875713
# 4            5  3.079565
# ...        ...       ...
# 45110   176267  4.000000
# 45111   176269  3.500000
# 45112   176271  5.000000
# 45113   176273  1.000000
# 45114   176275  3.000000
#
# [45115 rows x 2 columns]

# %%
#a['user_count']=
b=df2.groupby('movieId')['userId'].count().reset_index()
b
#a
# Out:
#        movieId  userId
# 0            1   66008
# 1            2   26060
# 2            3   15497
# 3            4    2981
# 4            5   15258
# ...        ...     ...
# 45110   176267       1
# 45111   176269       1
# 45112   176271       1
# 45113   176273       1
# 45114   176275       1
#
# [45115 rows x 2 columns]

# %%
a['user_count']=b['userId']
a
# Out:
#        movieId    rating  user_count
# 0            1  3.888157       66008
# 1            2  3.236953       26060
# 2            3  3.175550       15497
# 3            4  2.875713        2981
# 4            5  3.079565       15258
# ...        ...       ...         ...
# 45110   176267  4.000000           1
# 45111   176269  3.500000           1
# 45112   176271  5.000000           1
# 45113   176273  1.000000           1
# 45114   176275  3.000000           1
#
# [45115 rows x 3 columns]

# %%
c=df1.merge(a,on='movieId',how='left')
c
# Out:
#        movieId   imdbId    tmdbId    rating  user_count
# 0            1   114709     862.0  3.888157     66008.0
# 1            2   113497    8844.0  3.236953     26060.0
# 2            3   113228   15602.0  3.175550     15497.0
# 3            4   114885   31357.0  2.875713      2981.0
# 4            5   113041   11862.0  3.079565     15258.0
# ...        ...      ...       ...       ...         ...
# 45838   176269  6209470  439050.0  3.500000         1.0
# 45839   176271  2028550  111109.0  5.000000         1.0
# 45840   176273   303758   67758.0  1.000000         1.0
# 45841   176275     8536  227506.0  3.000000         1.0
# 45842   176279  6980792  461257.0       NaN         NaN
#
# [45843 rows x 5 columns]

# %%
c[c.duplicated(subset=['movieId'])]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId, rating, user_count]
# Index: []

# %%
c.to_csv('rating.csv',index=False)

# %%
c[c.duplicated()]
# Out:
# Empty DataFrame
# Columns: [movieId, imdbId, tmdbId, rating, user_count]
# Index: []

# %%
c.dtypes
# Out:
# movieId         int64
# imdbId          int64
# tmdbId        float64
# rating        float64
# user_count    float64
# dtype: object

# %%
c.to_csv('ratings.csv',index=False)

# %% [markdown]
# # Merging of dataframes

# %%
df3=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\cleaned_mvi_data.csv')

# %%
df3.head()
# Out:
#    adult    budget   mov_id   imdb_id original_language  \
# 0  False  30000000    862.0  114709.0                en
# 1  False  65000000   8844.0  113497.0                en
# 2  False         0  15602.0  113228.0                en
# 3  False  16000000  31357.0  114885.0                en
# 4  False         0  11862.0  113041.0                en
#
#                 original_title  popularity release_date      revenue  runtime  \
# 0                    Toy Story   21.946943   1995-10-30  373554033.0     81.0
# 1                      Jumanji   17.015539   1995-12-15  262797249.0    104.0
# 2             Grumpier Old Men   11.712900   1995-12-22          0.0    101.0
# 3            Waiting to Exhale    3.859495   1995-12-22   81452156.0    127.0
# 4  Father of the Bride Part II    8.387519   1995-02-10   76578911.0    106.0
#
#      status                                            tagline  \
# 0  Released                                                NaN
# ...

# %%
df3.shape
# Out:
# (45447, 16)

# %%
df3.dtypes
# Out:
# adult                   bool
# budget                 int64
# mov_id               float64
# imdb_id              float64
# original_language     object
# original_title        object
# popularity           float64
# release_date          object
# revenue              float64
# runtime              float64
# status                object
# tagline               object
# title                 object
# video                   bool
# vote_average         float64
# vote_count           float64
# dtype: object

# %%
d=df3.merge(c,how='left',left_on='mov_id',right_on='tmdbId')
d
# Out:
#        adult    budget    mov_id    imdb_id original_language  \
# 0      False  30000000     862.0   114709.0                en
# 1      False  65000000    8844.0   113497.0                en
# 2      False         0   15602.0   113228.0                en
# 3      False  16000000   31357.0   114885.0                en
# 4      False         0   11862.0   113041.0                en
# ...      ...       ...       ...        ...               ...
# 45489  False         0  439050.0  6209470.0                fa
# 45490  False         0  111109.0  2028550.0                tl
# 45491  False         0   67758.0   303758.0                en
# 45492  False         0  227506.0     8536.0                en
# 45493  False         0  461257.0  6980792.0                en
#
#                     original_title  popularity release_date      revenue  \
# 0                        Toy Story   21.946943   1995-10-30  373554033.0
# ...

# %%
d.drop(columns=['tmdbId'],inplace=True)

# %%
d.rename(columns={'movieId':'R_id'},inplace=True)

# %%
d
# Out:
#        adult    budget    mov_id    imdb_id original_language  \
# 0      False  30000000     862.0   114709.0                en
# 1      False  65000000    8844.0   113497.0                en
# 2      False         0   15602.0   113228.0                en
# 3      False  16000000   31357.0   114885.0                en
# 4      False         0   11862.0   113041.0                en
# ...      ...       ...       ...        ...               ...
# 45489  False         0  439050.0  6209470.0                fa
# 45490  False         0  111109.0  2028550.0                tl
# 45491  False         0   67758.0   303758.0                en
# 45492  False         0  227506.0     8536.0                en
# 45493  False         0  461257.0  6980792.0                en
#
#                     original_title  popularity release_date      revenue  \
# 0                        Toy Story   21.946943   1995-10-30  373554033.0
# ...

# %%
d.drop(columns=['tagline'],inplace=True)

# %%
d
# Out:
#        adult    budget    mov_id    imdb_id original_language  \
# 0      False  30000000     862.0   114709.0                en
# 1      False  65000000    8844.0   113497.0                en
# 2      False         0   15602.0   113228.0                en
# 3      False  16000000   31357.0   114885.0                en
# 4      False         0   11862.0   113041.0                en
# ...      ...       ...       ...        ...               ...
# 45489  False         0  439050.0  6209470.0                fa
# 45490  False         0  111109.0  2028550.0                tl
# 45491  False         0   67758.0   303758.0                en
# 45492  False         0  227506.0     8536.0                en
# 45493  False         0  461257.0  6980792.0                en
#
#                     original_title  popularity release_date      revenue  \
# 0                        Toy Story   21.946943   1995-10-30  373554033.0
# ...

# %%
df4=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\cast1.csv')

# %%
df4.head()
# Out:
#    cast_id                character                 credit_id  gender     id  \
# 0       14            Woody (voice)  52fe4284c3a36847f8024f95       2     31
# 1       15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2  12898
# 2       16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2   7167
# 3       17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2  12899
# 4       18              Rex (voice)  52fe4284c3a36847f8024fa5       2  12900
#
#             name  order                      profile_path  mov_id
# 0      Tom Hanks      0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg     862
# 1      Tim Allen      1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg     862
# 2    Don Rickles      2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg     862
# 3     Jim Varney      3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg     862
# 4  Wallace Shawn      4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg     862

# %%
df4.drop(columns=['profile_path','order','credit_id'],inplace=True)

# %%
df4.rename(columns={'id':'person_id'},inplace=True)

# %%
df4
# Out:
#         cast_id                character  gender  person_id  \
# 0            14            Woody (voice)       2         31
# 1            15   Buzz Lightyear (voice)       2      12898
# 2            16  Mr. Potato Head (voice)       2       7167
# 3            17       Slinky Dog (voice)       2      12899
# 4            18              Rex (voice)       2      12900
# ...         ...                      ...     ...        ...
# 562039        2                      NaN       2     544742
# 562040        3                      NaN       1    1090923
# 562041        4                      NaN       2    1136422
# 562042        5                      NaN       0    1261758
# 562043        6                      NaN       1      29199
#
#                      name  mov_id
# 0               Tom Hanks     862
# 1               Tim Allen     862
# 2             Don Rickles     862
# 3              Jim Varney     862
# 4           Wallace Shawn     862
# ...

# %%
e=d.merge(df4,on='mov_id',how='left')
e
# Out:
#         adult    budget    mov_id    imdb_id original_language  \
# 0       False  30000000     862.0   114709.0                en
# 1       False  30000000     862.0   114709.0                en
# 2       False  30000000     862.0   114709.0                en
# 3       False  30000000     862.0   114709.0                en
# 4       False  30000000     862.0   114709.0                en
# ...       ...       ...       ...        ...               ...
# 565064  False         0  227506.0     8536.0                en
# 565065  False         0  227506.0     8536.0                en
# 565066  False         0  227506.0     8536.0                en
# 565067  False         0  227506.0     8536.0                en
# 565068  False         0  461257.0  6980792.0                en
#
#              original_title  popularity release_date      revenue  runtime  \
# 0                 Toy Story   21.946943   1995-10-30  373554033.0     81.0
# ...

# %%
df5=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\crew.csv')

# %%
df5.head()
# Out:
#    Unnamed: 0                 credit_id department  gender     id         job  \
# 0           0  52fe4284c3a36847f8024f49  Directing       2   7879    Director
# 1           1  52fe4284c3a36847f8024f4f    Writing       2  12891  Screenplay
# 2           2  52fe4284c3a36847f8024f55    Writing       2      7  Screenplay
# 3           3  52fe4284c3a36847f8024f5b    Writing       2  12892  Screenplay
# 4           4  52fe4284c3a36847f8024f61    Writing       0  12893  Screenplay
#
#              name                      profile_path  mov_id
# 0   John Lasseter  /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg     862
# 1     Joss Whedon  /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg     862
# 2  Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg     862
# 3      Joel Cohen  /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg     862
# 4    Alec Sokolow  /v79vlRYi94BZUQnkkyznbGUZLjT.jpg     862

# %%
df5.drop(columns=['profile_path','credit_id','Unnamed: 0'],inplace=True)

# %%
df5
# Out:
#         department  gender       id                      job  \
# 0        Directing       2     7879                 Director
# 1          Writing       2    12891               Screenplay
# 2          Writing       2        7               Screenplay
# 3          Writing       2    12892               Screenplay
# 4          Writing       0    12893               Screenplay
# ...            ...     ...      ...                      ...
# 463831       Sound       0   549356  Original Music Composer
# 463832      Camera       2    58818  Director of Photography
# 463833   Directing       0  1085341                 Director
# 463834  Production       2  1195656                 Producer
# 463835   Directing       0  1344495                 Director
#
#                        name  mov_id
# 0             John Lasseter     862
# 1               Joss Whedon     862
# 2            Andrew Stanton     862
# 3                Joel Cohen     862
# 4              Alec Sokolow     862
# ...

# %%
df5.rename(columns={'id':'crew_id','job':'crew_job','name':'crew_name','gender':'crew_gender','department':'crew_department'},inplace=True)

# %%
df5
# Out:
#        crew_department  crew_gender  crew_id                 crew_job  \
# 0            Directing            2     7879                 Director
# 1              Writing            2    12891               Screenplay
# 2              Writing            2        7               Screenplay
# 3              Writing            2    12892               Screenplay
# 4              Writing            0    12893               Screenplay
# ...                ...          ...      ...                      ...
# 463831           Sound            0   549356  Original Music Composer
# 463832          Camera            2    58818  Director of Photography
# 463833       Directing            0  1085341                 Director
# 463834      Production            2  1195656                 Producer
# 463835       Directing            0  1344495                 Director
#
#                   crew_name  mov_id
# 0             John Lasseter     862
# 1               Joss Whedon     862
# ...

# %%
f=e.merge(df5,on='mov_id',how='left')
f
# Out:
#          adult    budget    mov_id    imdb_id original_language  \
# 0        False  30000000     862.0   114709.0                en
# 1        False  30000000     862.0   114709.0                en
# 2        False  30000000     862.0   114709.0                en
# 3        False  30000000     862.0   114709.0                en
# 4        False  30000000     862.0   114709.0                en
# ...        ...       ...       ...        ...               ...
# 9488784  False         0  227506.0     8536.0                en
# 9488785  False         0  227506.0     8536.0                en
# 9488786  False         0  227506.0     8536.0                en
# 9488787  False         0  227506.0     8536.0                en
# 9488788  False         0  461257.0  6980792.0                en
#
#               original_title  popularity release_date      revenue  runtime  \
# 0                  Toy Story   21.946943   1995-10-30  373554033.0     81.0
# ...

# %%
f.rename(columns={'name':'cast_name','gender':'cast_gender'},inplace=True)

# %%
f.columns
# Out:
# Index(['adult', 'budget', 'mov_id', 'imdb_id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'revenue', 'runtime',
#        'status', 'title', 'video', 'vote_average', 'vote_count', 'R_id',
#        'imdbId', 'rating', 'user_count', 'cast_id', 'character', 'cast_gender',
#        'person_id', 'cast_name', 'crew_department', 'crew_gender', 'crew_id',
#        'crew_job', 'crew_name'],
#       dtype='object')

# %%
f[['imdb_id','imdbId']]
# Out:
#            imdb_id   imdbId
# 0         114709.0   114709
# 1         114709.0   114709
# 2         114709.0   114709
# 3         114709.0   114709
# 4         114709.0   114709
# ...            ...      ...
# 9488784     8536.0     8536
# 9488785     8536.0     8536
# 9488786     8536.0     8536
# 9488787     8536.0     8536
# 9488788  6980792.0  6980792
#
# [9488789 rows x 2 columns]

# %%
f.drop(columns=['imdbId'],inplace=True)

# %%
f
# Out:
#          adult    budget    mov_id    imdb_id original_language  \
# 0        False  30000000     862.0   114709.0                en
# 1        False  30000000     862.0   114709.0                en
# 2        False  30000000     862.0   114709.0                en
# 3        False  30000000     862.0   114709.0                en
# 4        False  30000000     862.0   114709.0                en
# ...        ...       ...       ...        ...               ...
# 9488784  False         0  227506.0     8536.0                en
# 9488785  False         0  227506.0     8536.0                en
# 9488786  False         0  227506.0     8536.0                en
# 9488787  False         0  227506.0     8536.0                en
# 9488788  False         0  461257.0  6980792.0                en
#
#               original_title  popularity release_date      revenue  runtime  \
# 0                  Toy Story   21.946943   1995-10-30  373554033.0     81.0
# ...

# %%
df6=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\genres.csv')

# %%
df6.head()
# Out:
#    genre_id genre_name  mov_id
# 0        16  Animation   862.0
# 1        35     Comedy   862.0
# 2     10751     Family   862.0
# 3        12  Adventure  8844.0
# 4        14    Fantasy  8844.0

# %%
g=f.merge(df6,on='mov_id',how='left')
g
# Out:
#           adult    budget    mov_id    imdb_id original_language  \
# 0         False  30000000     862.0   114709.0                en
# 1         False  30000000     862.0   114709.0                en
# 2         False  30000000     862.0   114709.0                en
# 3         False  30000000     862.0   114709.0                en
# 4         False  30000000     862.0   114709.0                en
# ...         ...       ...       ...        ...               ...
# 24194962  False         0  227506.0     8536.0                en
# 24194963  False         0  227506.0     8536.0                en
# 24194964  False         0  227506.0     8536.0                en
# 24194965  False         0  227506.0     8536.0                en
# 24194966  False         0  461257.0  6980792.0                en
#
#                original_title  popularity release_date      revenue  runtime  \
# 0                   Toy Story   21.946943   1995-10-30  373554033.0     81.0
# ...

# %%
g[g.duplicated()]
# Out:
#           adult  budget    mov_id    imdb_id original_language  \
# 20885313  False       0  159849.0   173769.0                en
# 20885314  False       0  159849.0   173769.0                en
# 20885315  False       0  159849.0   173769.0                en
# 20885316  False       0  159849.0   173769.0                en
# 20885317  False       0  159849.0   173769.0                en
# ...         ...     ...       ...        ...               ...
# 24173533  False       0  265189.0  2121382.0                sv
# 24173534  False       0  265189.0  2121382.0                sv
# 24173535  False       0  265189.0  2121382.0                sv
# 24173536  False       0  265189.0  2121382.0                sv
# 24173537  False       0  265189.0  2121382.0                sv
#
#                             original_title  popularity release_date  \
# 20885313  Why We Fight: Divide and Conquer    0.473322   1943-01-01
# 20885314  Why We Fight: Divide and Conquer    0.473322   1943-01-01
# ...

# %%
g.drop_duplicates(inplace=True)

# %%
g.shape
# Out:
# (24193951, 30)

# %%
df7=pd.read_csv(r'C:\Users\sambangi.bindu\Downloads\Production_companies.csv')

# %%
df7.head()
# Out:
#                         name     id  movie_id
# 0    Pixar Animation Studios      3       862
# 1           TriStar Pictures    559      8844
# 2               Teitler Film   2550      8844
# 3  Interscope Communications  10201      8844
# 4               Warner Bros.   6194     15602

# %%
df7.rename(columns={'movie_id':'mov_id','id':'prodcompany_id','name':'prodcompanny_name'},inplace=True)

# %%
df7
# Out:
#                    prodcompanny_name  prodcompany_id  mov_id
# 0            Pixar Animation Studios               3     862
# 1                   TriStar Pictures             559    8844
# 2                       Teitler Film            2550    8844
# 3          Interscope Communications           10201    8844
# 4                       Warner Bros.            6194   15602
# ...                              ...             ...     ...
# 70459    20th Century Fox Television           16323   30840
# 70460  CanWest Global Communications           38978   30840
# 70461                    Sine Olivia           19653  111109
# 70462        American World Pictures            6165   67758
# 70463                      Yermoliev           88753  227506
#
# [70464 rows x 3 columns]

# %%
g.merge(df7,on='mov_id',how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 g.merge(df7,on='mov_id',how='left')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
# ...

# %%
g.shape
# Out:
# (24193951, 30)

# %%
g.to_csv('merged.csv',index=False)
